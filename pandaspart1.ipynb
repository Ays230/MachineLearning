# %% [markdown]
# <a href="https://colab.research.google.com/github/Ays230/MachineLearning/blob/main/pandaspart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
marka = ['BMW','TOYOTA','TESLA']
masinlar = pd.Series(marka)
masinlar
# Out:
# 0       BMW
# 1    TOYOTA
# 2     TESLA
# dtype: object

# %%
masinlar[1]
# Out:
# 'TOYOTA'

# %%
masinlar.values
# Out:
# array(['BMW', 'TOYOTA', 'TESLA'], dtype=object)

# %%
masinlar.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
masinlar = pd.Series(marka,index =['a','b','c'])
masinlar
# Out:
# a       BMW
# b    TOYOTA
# c     TESLA
# dtype: object

# %%
masinlar.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
masinlar['a']
# Out:
# 'BMW'

# %%
bal ={'Bayram':98,'Mehman':68,'Nazli':70}
a = pd.Series(bal)
a
# Out:
# Bayram    98
# Mehman    68
# Nazli     70
# dtype: int64

# %%
a['Mehman']
# Out:
# np.int64(68)

# %%
a[a>80]
# Out:
# Bayram    98
# dtype: int64

# %%
'Nazli' in a
# Out:
# True

# %%
a /10
# Out:
# Bayram    9.8
# Mehman    6.8
# Nazli     7.0
# dtype: float64

# %%
a.isnull()
# Out:
# Bayram    False
# Mehman    False
# Nazli     False
# dtype: bool

# %%
a.isnull().sum()
# Out:
# np.int64(0)

# %%
#strukturlasdirilmis cedvel seklinde
#strukturlasdirrilmamsi sekil audio ses kaydi
#asagdakini etmek ucun  qarsisina # yaz ctrl mm baas

# %% [markdown]
# #DataFrame

# %%
mar=pd.Series(['BMW','TESLA','TOYOTA'])
reng = pd.Series(['qara','ag','boz'])

# %%
masinlar=pd.DataFrame({'marka':mar,'reng':reng})
masinlar
# Out:
#     marka  reng
# 0     BMW  qara
# 1   TESLA    ag
# 2  TOYOTA   boz

# %%
data ={'ad':['Bayram','Maryam','Sevinc','Teymur','Jasmin','Ferman'],
       'cins':['k','q','q','k','q','k'],
       'bal':[67,78,69,54,45,89]}
df =pd.DataFrame(data)
df
# Out:
#        ad cins  bal
# 0  Bayram    k   67
# 1  Maryam    q   78
# 2  Sevinc    q   69
# 3  Teymur    k   54
# 4  Jasmin    q   45
# 5  Ferman    k   89

# %%
df.head() #ilk 5 setir
# Out:
#        ad cins  bal
# 0  Bayram    k   67
# 1  Maryam    q   78
# 2  Sevinc    q   69
# 3  Teymur    k   54
# 4  Jasmin    q   45

# %%
df.tail(2) # sondan verir
# Out:
#        ad cins  bal
# 4  Jasmin    q   45
# 5  Ferman    k   89

# %%
df.sample(2) #random setirler
# Out:
#        ad cins  bal
# 5  Ferman    k   89
# 3  Teymur    k   54

# %%
df= pd.DataFrame(data,columns = ['ad','cins','bal','yas'])
df
# Out:
#        ad cins  bal  yas
# 0  Bayram    k   67  NaN
# 1  Maryam    q   78  NaN
# 2  Sevinc    q   69  NaN
# 3  Teymur    k   54  NaN
# 4  Jasmin    q   45  NaN
# 5  Ferman    k   89  NaN

# %%
df['status']= 'Telebe'
df
# Out:
#        ad cins  bal  yas  status
# 0  Bayram    k   67  NaN  Telebe
# 1  Maryam    q   78  NaN  Telebe
# 2  Sevinc    q   69  NaN  Telebe
# 3  Teymur    k   54  NaN  Telebe
# 4  Jasmin    q   45  NaN  Telebe
# 5  Ferman    k   89  NaN  Telebe

# %%
df.isnull().sum()
# Out:
# ad        0
# cins      0
# bal       0
# yas       6
# status    0
# dtype: int64

# %%
df[['cins','yas']]
# Out:
#   cins  yas
# 0    k  NaN
# 1    q  NaN
# 2    q  NaN
# 3    k  NaN
# 4    q  NaN
# 5    k  NaN

# %%
df.ad
# Out:
# 0    Bayram
# 1    Maryam
# 2    Sevinc
# 3    Teymur
# 4    Jasmin
# 5    Ferman
# Name: ad, dtype: object

# %%
df.iloc[2] #index loc,hemin indexin melumatlarini series seklinde qaytarir
# Out:
# ad        Sevinc
# cins           q
# bal           69
# yas          NaN
# status    Telebe
# Name: 2, dtype: object

# %%
df.iloc[2,[2,3]]  #2ci setir (2,3 )sutun melumatlari
# Out:
# bal    69
# yas    18
# Name: 2, dtype: object

# %%
df['yas']= 18
df
# Out:
#        ad cins  bal  yas  status
# 0  Bayram    k   67   18  Telebe
# 1  Maryam    q   78   18  Telebe
# 2  Sevinc    q   69   18  Telebe
# 3  Teymur    k   54   18  Telebe
# 4  Jasmin    q   45   18  Telebe
# 5  Ferman    k   89   18  Telebe

# %%
df.loc[2,['bal']] #loc sutun adlarinin hansi indexde oldugunu bilir
# Out:
# bal    69
# Name: 2, dtype: object

# %%
df.loc[[2,5],['ad','yas']]
# Out:
#        ad  yas
# 2  Sevinc   18
# 5  Ferman   18

# %%
df['imtkec'] = df['bal']>50
df
# Out:
#        ad cins  bal  yas  status  imtkec
# 0  Bayram    k   67   18  Telebe    True
# 1  Maryam    q   78   18  Telebe    True
# 2  Sevinc    q   69   18  Telebe    True
# 3  Teymur    k   54   18  Telebe    True
# 4  Jasmin    q   45   18  Telebe   False
# 5  Ferman    k   89   18  Telebe    True

# %%
df.T
# Out:
#              0       1       2       3       4       5
# ad      Bayram  Maryam  Sevinc  Teymur  Jasmin  Ferman
# cins         k       q       q       k       q       k
# bal         67      78      69      54      45      89
# yas         18      18      18      18      18      18
# status  Telebe  Telebe  Telebe  Telebe  Telebe  Telebe
# imtkec    True    True    True    True   False    True

# %%
df
# Out:
#        ad cins  bal  yas  status  imtkec
# 0  Bayram    k   67   18  Telebe    True
# 1  Maryam    q   78   18  Telebe    True
# 2  Sevinc    q   69   18  Telebe    True
# 3  Teymur    k   54   18  Telebe    True
# 4  Jasmin    q   45   18  Telebe   False
# 5  Ferman    k   89   18  Telebe    True

# %%
df[0:4]
# Out:
#        ad cins  bal  yas  status  imtkec
# 0  Bayram    k   67   18  Telebe    True
# 1  Maryam    q   78   18  Telebe    True
# 2  Sevinc    q   69   18  Telebe    True
# 3  Teymur    k   54   18  Telebe    True

# %%
df.drop('imtkec',axis=1) #axis = 1 sutun axis=0 setir
# Out:
#        ad cins  bal  yas  status
# 0  Bayram    k   67   18  Telebe
# 1  Maryam    q   78   18  Telebe
# 2  Sevinc    q   69   18  Telebe
# 3  Teymur    k   54   18  Telebe
# 4  Jasmin    q   45   18  Telebe
# 5  Ferman    k   89   18  Telebe

# %%
df = df.drop('imtkec',axis= 1)

# %%
df
# Out:
#        ad cins  bal  yas  status
# 0  Bayram    k   67   18  Telebe
# 1  Maryam    q   78   18  Telebe
# 2  Sevinc    q   69   18  Telebe
# 3  Teymur    k   54   18  Telebe
# 4  Jasmin    q   45   18  Telebe
# 5  Ferman    k   89   18  Telebe

# %%
df.sort_index(ascending=False)
# Out:
#        ad cins  bal  yas  status
# 5  Ferman    k   89   18  Telebe
# 4  Jasmin    q   45   18  Telebe
# 3  Teymur    k   54   18  Telebe
# 2  Sevinc    q   69   18  Telebe
# 1  Maryam    q   78   18  Telebe
# 0  Bayram    k   67   18  Telebe

# %%
df.sort_index(axis = 1)
# Out:
#        ad  bal cins  status  yas
# 0  Bayram   67    k  Telebe   18
# 1  Maryam   78    q  Telebe   18
# 2  Sevinc   69    q  Telebe   18
# 3  Teymur   54    k  Telebe   18
# 4  Jasmin   45    q  Telebe   18
# 5  Ferman   89    k  Telebe   18

# %%
df.sort_values('bal',ascending = False)
# Out:
#        ad cins  bal  yas  status
# 5  Ferman    k   89   18  Telebe
# 1  Maryam    q   78   18  Telebe
# 2  Sevinc    q   69   18  Telebe
# 0  Bayram    k   67   18  Telebe
# 3  Teymur    k   54   18  Telebe
# 4  Jasmin    q   45   18  Telebe
